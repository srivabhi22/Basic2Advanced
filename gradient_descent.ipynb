# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import make_regression
from sklearn.linear_model import LinearRegression
from sklearn.datasets import make_blobs
from sklearn.model_selection import train_test_split

# %%
X,y = make_regression(n_samples=100, n_features=1, n_informative=1, n_targets=1,noise=20,random_state=13)


# Plot the data
plt.scatter(X, y)
plt.xlabel('x')
plt.ylabel('y')
plt.title('Synthetic Linear Regression Data')
plt.show()

# %%
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)
model=LinearRegression()
model.fit(x_train,y_train)
print(model.intercept_,model.coef_)
# Out:
# -2.6537533288365944 [27.66905703]

# %%
y_pred=model.predict(x_train)

plt.scatter(X, y)
plt.plot(x_train,y_pred,color='b')
plt.xlabel('x')
plt.ylabel('y')
plt.title('Synthetic Linear Regression Data')
plt.show()

# %%
#assume m=1.98200245 i.e. slope is constant and assume b=0 at the start
m=1
b=0
y_predicted=m*x_train.flatten()+b

plt.plot(x_train,y_predicted,color='g',label='manually drawn')
plt.plot(x_train,y_pred,color='b',label='system drawn')
plt.legend()

# %%
lr=0.001
b_pred=0
m_pred=1
# y_predicted=m_pred*x_train.flatten()+b_pred

# slope=-2*np.sum(y_train-y_predicted)
epochs=30

for i in range(epochs):
    y_predicted=m_pred*x_train.ravel()+b_pred
    
    loss_slope_b=-2*np.sum(y_train-y_predicted)
    loss_slope_m=-2*np.sum((y_train-y_predicted)*x_train.ravel())

    b_pred=b_pred-lr*loss_slope_b
    m_pred=m_pred-lr*loss_slope_m
#     print(f"diff:{b_new-b_old},slope:{slope},b_new:{b_new}")
#     if(b_new-b_old<0.0001):
#         break;
#     b_old=b_new
#     m_old=m_new
#     print(f"{y_predicted[0]}:y_pred,{b_new}:b_new,{slope}")

# %%
y_predicted=m_pred*x_train.flatten()+b_pred

plt.plot(x_train,y_predicted,color='g',label='manually drawn')
plt.plot(x_train,y_pred,color='b',label='system drawn')
plt.legend()
